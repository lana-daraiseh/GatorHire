# %% [markdown]
# Step 1: Loading Data

# %%
import io
import re
from datetime import datetime
import pandas as pd
import streamlit as st
from pypdf import PdfReader
import pdfplumber
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import fitz  # PyMuPDF

# %%
file_path = '/DraftMLResumeProject/parsed_resumes.csv'
try:
    df = pd.read_csv(file_path)
except:
    df = pd.read_csv("parsed_resumes.csv")      # manual read

# %%
# Print the shape of the dataset

print(f"There are {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# There are 4 rows and 18 columns.

# %%
# Display first 5 rows of Raw Data
display(df.head())
# Out:
#                                        file  pages  used_ocr  \
# 0          Anthony Franzino Resume 2025.pdf      1     False
# 1  Elliot Blain Computer Science Resume.pdf      2     False
# 2            Christian Schneider Resume.pdf      1     False
# 3             Lana Daraiseh TEST Resume.pdf      1     False
#
#                               name_guess  \
# 0                           leverage AI.
# 1  Bachelor of Science, Computer Science
# 2     Efficiently manage multiple tables
# 3              Project: Image Processing
#
#                                               emails  \
# 0  ajfranzino1@gmail.com, jdsaliba14@gmail.com, p...
# 1                                 njblain1@gmail.com
# 2                            Cdschneider27@gmail.com
# 3                             lanadaraiseh@gmail.com
#
#                                               phones  \
# 0  687695376, 863) 224-1745, 863) 255-2674, 863) ...
# 1                                      941) 416-7722
# 2                     407)-782-8481, 734375347\n2255
# 3                                      +966549842551
#
#                                             linkedin  github  \
# 0  https://www.linkedin.com/in/anthony-franzino-6...     NaN
# 1                                                NaN     NaN
# 2  https://www.linkedin.com/in/christian-schneide...     NaN
# 3                                                NaN     NaN
#
#                                 other_links skills_snippet  \
# 0                                       NaN            NaN
# 1  https://njblain1.wixsite.com/elliotblain            NaN
# 2                                       NaN            NaN
# 3                                       NaN              •
#
#                                    education_snippet  char_count   hs_gpa  \
# 0  EDUCATION AUGUST 2022 - PRESENT (Graduating Fa...        2025      NaN
# 1  Education Bachelor of Science, Computer Scienc...        3025      NaN
# 2  Education Bachelor of Science, Computer Scienc...        1610      NaN
# 3  EDUCATION University of Florida (UF) Gainesvil...        2537  3.8/4.0
#
#                 degree                                         university  \
# 0                  NaN             UNIVERSITY OF FLORIDA, GAINESVILLE, FL
# 1  Bachelor of Science  Gainesville, FL | njblain1@gmail.com | (941) 4...
# 2  Bachelor of Science                        llege Board SAT Participant
# 3               Master                                 hahran, KSA, 31311
#
#             programming_languages  internships_found graduation_date
# 0                      Typescript                NaN             NaN
# 1  C++, Java, Matlab, Python, Sql                NaN             NaN
# 2     C++, Html, Java, Javascript                NaN             NaN
# 3               C++, Java, Python                NaN        May 2025

# %%
# Information about Dataset
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   file                   4 non-null      object
#  1   pages                  4 non-null      int64
#  2   used_ocr               4 non-null      bool
#  3   name_guess             4 non-null      object
#  4   emails                 4 non-null      object
#  5   phones                 4 non-null      object
#  6   linkedin               2 non-null      object
#  7   github                 0 non-null      float64
#  8   other_links            1 non-null      object
#  9   skills_snippet         1 non-null      object
#  10  education_snippet      4 non-null      object
#  11  char_count             4 non-null      int64
#  12  hs_gpa                 1 non-null      object
#  13  degree                 3 non-null      object
#  14  university             4 non-null      object
#  15  programming_languages  4 non-null      object
#  16  internships_found      0 non-null      float64
#  17  graduation_date        1 non-null      object
# dtypes: bool(1), float64(2), int64(2), object(13)
# memory usage: 680.0+ bytes
# None

# %%
# Print Summary Statistics
display(df.describe(include = "all"))
# Out:
#                                     file  pages used_ocr    name_guess  \
# count                                  4   4.00        4             4
# unique                                 4    NaN        1             4
# top     Anthony Franzino Resume 2025.pdf    NaN    False  leverage AI.
# freq                                   1    NaN        4             1
# mean                                 NaN   1.25      NaN           NaN
# std                                  NaN   0.50      NaN           NaN
# min                                  NaN   1.00      NaN           NaN
# 25%                                  NaN   1.00      NaN           NaN
# 50%                                  NaN   1.00      NaN           NaN
# 75%                                  NaN   1.25      NaN           NaN
# max                                  NaN   2.00      NaN           NaN
#
#                                                    emails  \
# count                                                   4
# unique                                                  4
# top     ajfranzino1@gmail.com, jdsaliba14@gmail.com, p...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                    phones  \
# count                                                   4
# unique                                                  4
# top     687695376, 863) 224-1745, 863) 255-2674, 863) ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                  linkedin  github  \
# count                                                   2     0.0
# unique                                                  2     NaN
# top     https://www.linkedin.com/in/anthony-franzino-6...     NaN
# freq                                                    1     NaN
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#                                      other_links skills_snippet  \
# count                                          1              1
# unique                                         1              1
# top     https://njblain1.wixsite.com/elliotblain              •
# freq                                           1              1
# mean                                         NaN            NaN
# std                                          NaN            NaN
# min                                          NaN            NaN
# 25%                                          NaN            NaN
# 50%                                          NaN            NaN
# 75%                                          NaN            NaN
# max                                          NaN            NaN
#
#                                         education_snippet   char_count  \
# count                                                   4     4.000000
# unique                                                  4          NaN
# top     EDUCATION AUGUST 2022 - PRESENT (Graduating Fa...          NaN
# freq                                                    1          NaN
# mean                                                  NaN  2299.250000
# std                                                   NaN   614.686031
# min                                                   NaN  1610.000000
# 25%                                                   NaN  1921.250000
# 50%                                                   NaN  2281.000000
# 75%                                                   NaN  2659.000000
# max                                                   NaN  3025.000000
#
#          hs_gpa               degree                              university  \
# count         1                    3                                       4
# unique        1                    2                                       4
# top     3.8/4.0  Bachelor of Science  UNIVERSITY OF FLORIDA, GAINESVILLE, FL
# freq          1                    2                                       1
# mean        NaN                  NaN                                     NaN
# std         NaN                  NaN                                     NaN
# min         NaN                  NaN                                     NaN
# 25%         NaN                  NaN                                     NaN
# 50%         NaN                  NaN                                     NaN
# 75%         NaN                  NaN                                     NaN
# max         NaN                  NaN                                     NaN
#
#        programming_languages  internships_found graduation_date
# count                      4                0.0               1
# unique                     4                NaN               1
# top               Typescript                NaN        May 2025
# freq                       1                NaN               1
# mean                     NaN                NaN             NaN
# std                      NaN                NaN             NaN
# min                      NaN                NaN             NaN
# 25%                      NaN                NaN             NaN
# 50%                      NaN                NaN             NaN
# 75%                      NaN                NaN             NaN
# max                      NaN                NaN             NaN

# %%
# Display Columns names
df.columns
# Out:
# Index(['file', 'pages', 'used_ocr', 'name_guess', 'emails', 'phones',
#        'linkedin', 'github', 'other_links', 'skills_snippet',
#        'education_snippet', 'char_count', 'hs_gpa', 'degree', 'university',
#        'programming_languages', 'internships_found', 'graduation_date'],
#       dtype='object')

# %% [markdown]
# Step 2: Exploratory Data Analysis

# %%
# Select only numerical columns
numerical_df = df.select_dtypes(include=['number'])

# Generate a heatmap for the correlation matrix
plt.figure(figsize=(12, 8))  # Set the figure size
correlation_matrix = numerical_df.corr()  # Compute the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Add a title
plt.title("Correlation Heatmap", fontsize=16)
plt.show()

# %%
# Feature Engineering to handle multicolinearity




# Then remove the original instances
